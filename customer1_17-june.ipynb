# %%
import pandas as pd

# %%
df = pd.read_csv("us_customer_data 1.csv")
df1 = pd.read_csv("transaction_data.csv")

# %%
df.head(5)
# Out:
#    customer_id              name                        email         phone  \
# 0            1     Michelle Kidd           vayala@example.net  619-723-4258
# 1            2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2            3      Larry Torres         dsanchez@example.net  810-256-4505
# 3            4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4            5  Matthew Phillips        qwilliams@example.com  220-763-3522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status
# 0           Gold
# 1         Silver
# 2         Bronze
# ...

# %%
df1.head(5)
# Out:
#    transaction_id  customer_id   amount     transaction_date product_category  \
# 0               1          565  2992.47  2025-03-10 01:20:54           Sports
# 1               2          323  2041.87  2025-01-02 15:24:19         Clothing
# 2               3          398   107.35  2025-02-16 03:49:01           Beauty
# 3               4           19      NaN  2025-04-30 15:26:23           Sports
# 4               5          547  3063.28  2025-06-14 04:28:53         Clothing
#
#   payment_method store_location
# 0     Debit Card       New York
# 1           Cash       New York
# 2     Debit Card         Online
# 3     Debit Card    Los Angeles
# 4         PayPal    Los Angeles

# %%
df.describe()
# Out:
#        customer_id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              950 non-null    object
#  3   phone              984 non-null    object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
dfnew = pd.merge(df,df1,on='customer_id',how = 'outer')

# %%
dfnew.head(5)
# Out:
#    customer_id              name                        email         phone  \
# 0            1     Michelle Kidd           vayala@example.net  619-723-4258
# 1            2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2            3      Larry Torres         dsanchez@example.net  810-256-4505
# 3            4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4            5  Matthew Phillips        qwilliams@example.com  220-763-3522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status  transaction_id   amount     transaction_date  \
# ...

# %%
dfnew.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1348    False
# 1349    False
# 1350    False
# 1351    False
# 1352    False
# Length: 1353, dtype: bool

# %%
dfnew.duplicated().sum()
# Out:
# np.int64(0)

# %%
dfnew.isnull().sum()
# Out:
# customer_id            0
# name                   0
# email                 56
# phone                 24
# address                0
# registration_date      0
# loyalty_status         0
# transaction_id       353
# amount               403
# transaction_date     353
# product_category     353
# payment_method       353
# store_location       353
# dtype: int64

# %%
dfnew.loc[dfnew['email'].isnull(),'email'] = dfnew['name'].str.lower() + '@example.com'

# %%
dfnew.head(50)
# Out:
#     customer_id                   name                        email  \
# 0             1          Michelle Kidd           vayala@example.net
# 1             2            Brad Newton  taylorcatherine@example.net
# 2             3           Larry Torres         dsanchez@example.net
# 3             4         Kimberly Price    jessicaknight@example.com
# 4             5       Matthew Phillips        qwilliams@example.com
# 5             6  Darrell Gallagher DVM      larryharris@example.org
# 6             7           Louis Miller  patriciaelliott@example.org
# 7             7           Louis Miller  patriciaelliott@example.org
# 8             8    Melissa Galloway MD   watsonbenjamin@example.net
# 9             9         Matthew Harvey          bgaines@example.net
# 10           10           Rachel White     whitemichael@example.org
# 11           10           Rachel White     whitemichael@example.org
# 12           10           Rachel White     whitemichael@example.org
# ...

# %%
dfnew.isnull().sum()
# Out:
# customer_id            0
# name                   0
# email                  0
# phone                 24
# address                0
# registration_date      0
# loyalty_status         0
# transaction_id       353
# amount               403
# transaction_date     353
# product_category     353
# payment_method       353
# store_location       353
# dtype: int64

# %%
dfnew.loc[dfnew['phone'].isnull(),'phone'] = 'Not Available'

# %%
dfnew.isnull().sum()
# Out:
# customer_id            0
# name                   0
# email                  0
# phone                  0
# address                0
# registration_date      0
# loyalty_status         0
# transaction_id       353
# amount               403
# transaction_date     353
# product_category     353
# payment_method       353
# store_location       353
# dtype: int64

# %%
dfnew.loc[dfnew['transaction_id'].isnull(),'transaction_id'] = 'Not Available'
dfnew.loc[dfnew['transaction_date'].isnull(),'transaction_date'] = 'Not Available'
dfnew.loc[dfnew['product_category'].isnull(),'product_category'] = 'Not Available'

# %%
dfnew.loc[dfnew['payment_method'].isnull(),'payment_method'] = 'Not Available'
dfnew.loc[dfnew['store_location'].isnull(),'store_location'] = 'Not Available'

# %%
dfnew.isnull().sum()
# Out:
# customer_id             0
# name                    0
# email                   0
# phone                   0
# address                 0
# registration_date       0
# loyalty_status          0
# transaction_id          0
# amount                403
# transaction_date        0
# product_category        0
# payment_method          0
# store_location          0
# store_location       1000
# dtype: int64

# %%
dfnew.dropna(dfnew['store_location '].isull(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9300\1808963038.py in ?()
# ----> 1 dfnew.dropna(dfnew['store_location '].isull(), inplace=True)
#
# c:\Users\Avi\OneDrive - Kasmo Digital Private Limited\Desktop\Python_tutorial1\env1\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isull'

# %%
dfnew = dfnew.drop('store_location ', axis=1)

# %%
dfnew.isnull().sum()
# Out:
# customer_id            0
# name                   0
# email                  0
# phone                  0
# address                0
# registration_date      0
# loyalty_status         0
# transaction_id         0
# amount               403
# transaction_date       0
# product_category       0
# payment_method         0
# store_location         0
# dtype: int64

# %%
dfnew.loc[dfnew['amount'].isnull(),'amount'] = dfnew['amount'].mean()

# %%
dfnew.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
dfnew.head(10)
# Out:
#    customer_id                   name                        email  \
# 0            1          Michelle Kidd           vayala@example.net
# 1            2            Brad Newton  taylorcatherine@example.net
# 2            3           Larry Torres         dsanchez@example.net
# 3            4         Kimberly Price    jessicaknight@example.com
# 4            5       Matthew Phillips        qwilliams@example.com
# 5            6  Darrell Gallagher DVM      larryharris@example.org
# 6            7           Louis Miller  patriciaelliott@example.org
# 7            7           Louis Miller  patriciaelliott@example.org
# 8            8    Melissa Galloway MD   watsonbenjamin@example.net
# 9            9         Matthew Harvey          bgaines@example.net
#
#           phone                                            address  \
# 0  619-723-4258                        USNS Santiago, FPO AE 80872
# 1  537-674-1158  38783 Oliver Street, West Kristenborough, MT 9...
# ...

# %%
dfnew['phone'] = dfnew['phone'].str.replace(r"[^0-9]", "", regex = True)

# %%
dfnew.head(10)
# Out:
#    customer_id                   name                        email  \
# 0            1          Michelle Kidd           vayala@example.net
# 1            2            Brad Newton  taylorcatherine@example.net
# 2            3           Larry Torres         dsanchez@example.net
# 3            4         Kimberly Price    jessicaknight@example.com
# 4            5       Matthew Phillips        qwilliams@example.com
# 5            6  Darrell Gallagher DVM      larryharris@example.org
# 6            7           Louis Miller  patriciaelliott@example.org
# 7            7           Louis Miller  patriciaelliott@example.org
# 8            8    Melissa Galloway MD   watsonbenjamin@example.net
# 9            9         Matthew Harvey          bgaines@example.net
#
#         phone                                            address  \
# 0  6197234258                        USNS Santiago, FPO AE 80872
# 1  5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# ...

# %%
dfnew.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
dfnew['country_code']= dfnew['address'].str[-8:-6]

# %%
dfnew = dfnew.drop('country_code',axis =1)

# %%
dfnew.head(5)
# Out:
#    customer_id              name                        email       phone  \
# 0            1     Michelle Kidd           vayala@example.net  6197234258
# 1            2       Brad Newton  taylorcatherine@example.net  5376741158
# 2            3      Larry Torres         dsanchez@example.net  8102564505
# 3            4    Kimberly Price    jessicaknight@example.com  4232229779
# 4            5  Matthew Phillips        qwilliams@example.com  2207633522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status transaction_id       amount     transaction_date  \
# ...

# %%
dfx = pd.read_csv('countrycodes.csv',engine ='python',on_bad_lines='skip')

# %%
dfx.columns = dfx.columns.str.strip()

# %%
dfx = dfx.drop('Country', axis=1)

# %%
dfx = dfx.rename(columns={'ISO2': 'country_code'})

# %%
dfx.head(5)
# Out:
#   country_code CallingCode
# 0           AF          93
# 1           AL         355
# 2           DZ         213
# 3           AD         376
# 4           AO         244

# %%
dfnew = pd.merge(dfnew,dfx,on ='country_code',how='left')

# %%
dfnew.head(5)
# Out:
#    customer_id              name                        email       phone  \
# 0            1     Michelle Kidd           vayala@example.net  6197234258
# 1            2       Brad Newton  taylorcatherine@example.net  5376741158
# 2            3      Larry Torres         dsanchez@example.net  8102564505
# 3            4    Kimberly Price    jessicaknight@example.com  4232229779
# 4            5  Matthew Phillips        qwilliams@example.com  2207633522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status transaction_id       amount     transaction_date  \
# ...

# %%
dfnew.loc[dfnew['CallingCode'].isnull(),'CallingCode']='1'

# %%
dfnew.head(5)
# Out:
#    customer_id              name                        email       phone  \
# 0            1     Michelle Kidd           vayala@example.net  6197234258
# 1            2       Brad Newton  taylorcatherine@example.net  5376741158
# 2            3      Larry Torres         dsanchez@example.net  8102564505
# 3            4    Kimberly Price    jessicaknight@example.com  4232229779
# 4            5  Matthew Phillips        qwilliams@example.com  2207633522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status transaction_id       amount     transaction_date  \
# ...

# %%
dfnew.loc[dfnew['phone'].notna(),'phone']= "+" + dfnew['CallingCode'] + " " + dfnew['phone']

# %%
dfnew.head(5)
# Out:
#    customer_id              name                        email  \
# 0            1     Michelle Kidd           vayala@example.net
# 1            2       Brad Newton  taylorcatherine@example.net
# 2            3      Larry Torres         dsanchez@example.net
# 3            4    Kimberly Price    jessicaknight@example.com
# 4            5  Matthew Phillips        qwilliams@example.com
#
#              phone                                            address  \
# 0  +971 6197234258                        USNS Santiago, FPO AE 80872
# 1  +356 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# 2    +1 8102564505     6845 Steele Turnpike, West Erikabury, UT 37487
# 3    +1 4232229779         1631 Alexis Meadows, Lake Amanda, CA 75179
# 4    +1 2207633522  2274 Williams Heights Suite 895, Andersonhaven...
#
#   registration_date loyalty_status transaction_id       amount  \
# 0        25-01-2025           Gold            8.0  2652.570000
# ...

# %%
df.loc[567]
# Out:
# customer_id                                                     568
# name                                                   Erin Richard
# email                                      juliagardner@example.net
# phone                                                  768-837-5244
# address              0505 Robert Greens, Port Heatherstad, KY 47124
# registration_date                                        13-11-2024
# loyalty_status                                               Bronze
# Name: 567, dtype: object

# %%
df.head(600)
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 595          596     Carol Shaffer       burnsscott@example.org  772-782-9223
# 596          597     Autumn Jordan         hjohnson@example.com  131-995-2389
# 597          598     Melissa Adams          aimee17@example.net  786-827-2392
# 598          599     Jeremy Sparks          qwillis@example.com  602-942-4637
# 599          600      Jeffrey Dean    brentsullivan@example.net  422-804-7399
#
# ...

# %%
print(dfnew.head(600).to_string(index=False))
# Out:
#  customer_id                    name                          email           phone                                                        address registration_date loyalty_status transaction_id      amount    transaction_date product_category payment_method store_location country_code CallingCode
#            1           Michelle Kidd             vayala@example.net +971 6197234258                                    USNS Santiago, FPO AE 80872        25-01-2025           Gold            8.0 2652.570000 2025-04-19 14:46:00             Home    Credit Card       New York           AE         971
#            2             Brad Newton    taylorcatherine@example.net +356 5376741158             38783 Oliver Street, West Kristenborough, MT 99752        13-07-2023         Silver  Not Available 2532.550126       Not Available    Not Available  Not Available  Not Available           MT         356
# ...

# %%
dfnew.iloc[567]
# Out:
# customer_id                                                      410
# name                                                 Rebecca Roberts
# email                                              nhill@example.org
# phone                                                  +1 7234854699
# address              6414 Michael Trace, South Christopher, HI 58174
# registration_date                                         20-10-2023
# loyalty_status                                                Silver
# transaction_id                                                 772.0
# amount                                                       3895.36
# transaction_date                                 2025-01-25 13:45:04
# product_category                                              Sports
# payment_method                                            Debit Card
# store_location                                                Online
# country_code                                                      HI
# ...

# %%
##3

newdata = dfnew.loc[dfnew['amount'].astype(float) > dfnew['amount'].mean()]

# %%
newdata1 = dfnew.loc[dfnew['amount'].astype(float) > 1000]

# %%
print(len(newdata))
# Out:
# 482

# %%
newdata.head(5)
# Out:
#     customer_id               name                        email  \
# 0             1      Michelle Kidd           vayala@example.net
# 6             7       Louis Miller  patriciaelliott@example.org
# 10           10       Rachel White     whitemichael@example.org
# 11           10       Rachel White     whitemichael@example.org
# 14           12  Christine Delgado         yfarrell@example.net
#
#               phone                                      address  \
# 0   +971 6197234258                  USNS Santiago, FPO AE 80872
# 6     +1 1988627105  02590 Marshall Well, Sheppardland, CT 88067
# 10  +972 4107299740    6182 Brown Mountain, South Gary, IL 29016
# 11  +972 4107299740    6182 Brown Mountain, South Gary, IL 29016
# 14    +1 3108349008             PSC 4025, Box 2078, APO AA 61121
#
#    registration_date loyalty_status transaction_id   amount  \
# 0         25-01-2025           Gold            8.0  2652.57
# 6         30-09-2024           Gold          470.0  3241.66
# ...

# %%
dfnew.to_csv('C:\\Users\\Avi\\OneDrive - Kasmo Digital Private Limited\\Desktop\\Python_tutorial1\\final_output.csv', index=False)
